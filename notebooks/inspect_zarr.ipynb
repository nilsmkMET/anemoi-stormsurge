# %%
from anemoi.datasets import open_dataset

# %%
file = '/lustre/storeB/users/nilsmk/Forcing/nordic4km_stress/n3e5_remake/zarr/nordic4_surge_atmos_1980_Pair.zarr'

# %%
ds = open_dataset(file)
# Out:
# /home/nilsmk/venv/anemoi/lib/python3.10/site-packages/anemoi/utils/config.py:207: UserWarning: Mofifying and instance of DotDict(). This class is intended to be immutable.
#   warnings.warn("Mofifying and instance of DotDict(). This class is intended to be immutable.")

# %%
ds.dates
# Out:
# array(['1980-01-01T00:00:00', '1980-01-01T01:00:00',
#        '1980-01-01T02:00:00', ..., '1980-12-31T21:00:00',
#        '1980-12-31T22:00:00', '1980-12-31T23:00:00'],
#       shape=(8784,), dtype='datetime64[s]')
